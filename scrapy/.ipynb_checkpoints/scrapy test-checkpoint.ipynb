# %%
import requests
from scrapy.http import TextResponse
import json

# %%
url = 'https://smartstore.naver.com/lingerwater/products/2796364821/reviews/page.json?page=1&size=30&sortType=REVIEW_RANKING&contentType=BEST'
headers = {'referer':'https://smartstore.naver.com/lingerwater/products/2800118009'}
rep = requests.get(url, headers=headers)
response = TextResponse(rep.url, body=rep.text, encoding="utf-8")

# %%
print(response.text)
# Out:
# {
# 	"bSuccess" : true,
# 	"htReturnValue" : {
# 		"message" : "",
# 		"gridType":"",
# 		"pagedResult" : {
# 			"content" : [{"id":821311268,"reviewScore":5,"writerId":"lsk9****","writerProfileImageUrl":"https://img-shop.pstatic.net/front/common/profile_default.png","purchasedProductName":"[셀프 수분 보충] 링티 1박스 (10회분, 레몬/복숭아 선택)","purchasedOptionContents":"구성선택: 링티 레몬맛 1박스 (10회분)","createdDate":"2020-03-19 17:53:36","best":true,"repurchase":false,"afterMonth":false,"freeTrialReview":false,"helpCount":3,"help":false,"contentType":"VIDEO","contents":"우선 디자인이 깔끔하고 예뻐요! 사실 효과를 기대한것보다 커피를 조금이라도 덜 마셔보자며,, 구입했은데, 오늘은 링티 덕분에 커피 1잔만 마셨네요&gt;.&lt;\n광고보니까 물에 섞이는 모습이 예뻐서 사무실 구석에서 숨죽이며 찍어봤슴당! 몰랐는데 대량으로 사면 엄청 저렴해지네요~ 다음엔 대량으로 사야겠다는.. \n후기보니까 맛이 이상하다는 평이 많아서 조큼 걱정했는데, 찬물에 마시니까 앵간하니 좋네요^.^\n요즘 마스크때문에 피부가 퍼석하니 난리인데, 수,,분^^ 보충해주면 그래도 덜 하겠죠..\n암튼 저는 만족임당!","comments":[{"id":229326860,"commentContent":"안녕하세요 고객님, 링티입니다. 사무실 구석에서 숨죽이며 작성하신 고객님의 모습을 상상하니 미소가 지어집니다^^ 목숨건 영상 감사드립니다. 마스크로 상한 피부에 링티가 조금이나마 도움이 되길 간절히 바라며, 앞으로도 고객만족을 위해 최선을 다하겠습니다^^","createdDate":"2020-03-27 17:44:03","blind":false}],"resources":[{"resourceUrl":"https://phinf.pstatic.net/image.nmv/shopnbuyer_2020_03_19_0/ee4ce200-69be-11ea-8773-505dacfba98a_03.jpg","type":"M","width":1280,"height":720,"inKey":null,"vid":"99E69A873C4E6008B8CE343B1734C0A7D68A","serviceId":"22","gifImage":false,"tagName":"","description":"섞이는게 예쁘다면서 섞이는부분은 찍지도 못했다면서,,^^;;"}],"reportable":true,"reportStatusCheckUrl":null,"userSizeText":null,"parentReviewSeq":null,"highLightedContent":"우선 디자인이 깔끔하고 예뻐요! 사실 효과를 기대한것보다 커피를 조금이라도 덜 마셔보자며,, 구입했은데, 오늘은 링티 덕분에 커피 1잔만 마셨네요&gt;.&lt;\n광고보니까 물에 섞이는 모습이 예뻐서 사무실 구석에서 숨죽이며 찍어봤슴당! 몰랐는데 대량으로 사면 엄청 저렴해지네요~ 다음엔 대량으로 사야겠다는.. \n후기보니까 맛이 이상하다는 평이 많아서 조큼 걱정했는데, 찬물에 마시니까 앵간하니 좋네요^.^\n요즘 마스크때문에 피부가 퍼석하니 난리인데, 수,,분^^ 보충해주면 그래도 덜 하겠죠..\n암튼 저는 만족임당!","channelServiceType":null,"visible":true,"eventSeq":null,"eventTitle":"","representResource":{"resourceUrl":"https://phinf.pstatic.net/image.nmv/shopnbuyer_2020_03_19_0/ee4ce200-69be-11ea-8773-505dacfba98a_03.jpg","type":"M","width":1280,"height":720,"inKey":null,"vid":"99E69A873C4E6008B8CE343B1734C0A7D68A","serviceId":"22","gifImage":false,"tagName":"","description":"섞이는게 예쁘다면서 섞이는부분은 찍지도 못했다면서,,^^;;"},"reviewScorePercent":100},{"id":821294452,"reviewScore":5,"writerId":"rosa****","writerProfileImageUrl":"https://img-shop.pstatic.net/front/common/profile_default.png","purchasedProductName":"[셀프 수분 보충] 링티 1박스 (10회분, 레몬/복숭아 선택)","purchasedOptionContents":"구성선택: 링티 레몬맛 1박스 (10회분)","createdDate":"2020-03-19 17:32:26","best":true,"repurchase":false,"afterMonth":false,"freeTrialReview":false,"helpCount":1,"help":false,"contentType":"PHOTO","contents":"☆☆실구매 솔직후기☆☆\n코로나19로 수분보충이 더더욱 중요하다고 해서 검색하다가 링티를 찾게 되었어요. 일반 생수는 먹기가 너무 힘들거든요...ㅜ\n원래 뭘 살때 엄청 신중하게 구매하는 편인데 링티는 일단 리뷰도 엄청 많았고, 또 평이 굉장히 좋더라구요! 이 많은걸 조작할수는 없잖아요?\n그리고 판매자님께서 고객 한명한명한테 달아주시는 답글도 너무 정성스러운것 같고 이부분에서 더욱 더 신뢰하게 되었어요! 그래서 일단 구매했습니다. 결론적으로 너무너무 만족해요!!\n너무 달지않은 맛이라 생수 500ml 완전 꿀떡꿀떡 넘어가구요~ 수분보충 확실히 되는 느낌이에요! 코로나 때문에 몸이 조금만 이상해도 신경쓰여서 링티 한잔 마시니까 거짓말처럼 회복 됐어요! 진짜 신기해요 이거.. 물건인듯!!!!!! \n후기 보다보면 제품이 너무 좋다고, 만들어주신분께 감사하다는 후기가 많았는데 직접 먹어보니 왜그리 극찬하는지 알것같네요!! \n저도 앞으로는 링티 단골고객이 될것 같은 예감이에요&gt;&lt;&hearts;","comments":[{"id":229326515,"commentContent":"안녕하세요 고객님, 링티입니다. 신중하게 소비를 하시는 고객님께서 링티를 믿고 구매해주심에 너무나 감사드립니다. 링티로 인해 조금 더 건강한 하루를 보내실 수 있어 영광입니다. 하루 한두잔의 링티와 함께 코로나19도 거뜬히 이겨내 보아요^^","createdDate":"2020-03-27 17:41:19","blind":false}],"resources":[{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20200319_69/1584605871538jxVDV_JPEG/KakaoTalk_20200319_171626620_02.jpg","type":"I","width":3024,"height":4032,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":""},{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20200319_220/1584605878936AH8mS_JPEG/KakaoTalk_20200319_171626620_01.jpg","type":"I","width":3024,"height":3115,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":""}],"reportable":true,"reportStatusCheckUrl":null,"userSizeText":null,"parentReviewSeq":null,"highLightedContent":"☆☆실구매 솔직후기☆☆\n코로나19로 수분보충이 더더욱 중요하다고 해서 검색 ...
# 			"number" : 1,
# 			"size" : 30,
# 			"totalPages" : 3,
# 			"totalElements" :90
# 		}
# 	}
# }

# %%
import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy import Request

# %%
class TestSpider(scrapy.Spider):
    name = 'test'
    start_urls = [
        'https://smartstore.naver.com/lingerwater/products/2800118009',
    ]

    def start_requests(self):
        headers = {'referer':'https://smartstore.naver.com/lingerwater/products/2800118009'}
        cookies = {}
        yield Request('https://smartstore.naver.com/lingerwater/products/2796364821/reviews/page.json?page=2&size=30&sortType=REVIEW_RANKING&contentType=ALL&topicCode=',
                      headers = headers,
                      cookies = cookies,
                      callback=self.parse, method='GET')

    def parse(self, response):
        print(response.text)
        with open('../data/data_content.json', 'w') as file:
            file.write(response.text)

# %%
process = CrawlerProcess()
process.crawl(TestSpider)
# Out:
# 2020-06-11 09:51:24 [scrapy.utils.log] INFO: Scrapy 1.6.0 started (bot: scrapybot)
# 2020-06-11 09:51:24 [scrapy.utils.log] INFO: Versions: lxml 4.5.0.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 20.3.0, Python 3.7.6 (default, Jan  8 2020, 20:23:39) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 19.1.0 (OpenSSL 1.1.1g  21 Apr 2020), cryptography 2.8, Platform Windows-7-6.1.7601-SP1
# 2020-06-11 09:51:24 [scrapy.crawler] INFO: Overridden settings: {}
# 2020-06-11 09:51:24 [scrapy.extensions.telnet] INFO: Telnet Password: e5b3db021975ade7
# 2020-06-11 09:51:25 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-06-11 09:51:25 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-06-11 09:51:25 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-06-11 09:51:25 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-06-11 09:51:25 [scrapy.core.engine] INFO: Spider opened
# 2020-06-11 09:51:25 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-06-11 09:51:25 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023

# %%
process.start()
# Out:
# 2020-06-11 09:51:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://smartstore.naver.com/lingerwater/products/2796364821/reviews/page.json?page=2&size=30&sortType=REVIEW_RANKING&contentType=ALL&topicCode=> (referer: https://smartstore.naver.com/lingerwater/products/2800118009)
# 2020-06-11 09:51:29 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-06-11 09:51:29 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 405,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 50704,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 6, 11, 0, 51, 29, 175000),
#  'log_count/DEBUG': 1,
#  'log_count/INFO': 9,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 6, 11, 0, 51, 25, 459000)}
# 2020-06-11 09:51:29 [scrapy.core.engine] INFO: Spider closed (finished)
# {
# 	"bSuccess" : true,
# 	"htReturnValue" : {
# 		"message" : "",
# 		"gridType":"",
# 		"pagedResult" : {
# 			"content" : [{"id":868376621,"reviewScore":5,"writerId":"park****","writerProfileImageUrl":"https://img-shop.pstatic.net/front/common/profile_default.png","purchasedProductName":"[10%할인] 링티 1박스 (10회분, 레몬/복숭아 선택) + 추가2포","purchasedOptionContents":"구성선택: 복숭아맛 1박스+2포 샘플","createdDate":"2020-06-03 13:54:26","best":false,"repurchase":false,"afterMonth":false,"freeTrialReview":false,"helpCount":0,"help":false,"contentType":"PHOTO","contents":"맛도 좋고 진짜 피로도가 덜해지고 잠도 잘와요  이렇게나 수분이 중요하구나 느끼네요","comments":[],"resources":[{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20200603_295/1591160060432TCAEj_JPEG/20200528_185007.jpg","type":"I","width":3000,"height":4000,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":""}],"reportable":true,"reportStatusCheckUrl":null,"userSizeText":null,"parentReviewSeq":null,"highLightedContent":"맛도 좋고 진짜 피로도가 덜해지고 잠도 잘와요  이렇게나 수분이 중요하구나 느끼네요","channelServiceType":null,"visible":true,"eventSeq":null,"eventTitle":"","representResource":{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20200603_295/1591160060432TCAEj_JPEG/20200528_185007.jpg","type":"I","width":3000,"height":4000,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":""},"reviewScorePercent":100},{"id":861267350,"reviewScore":4,"writerId":"oka8****","writerProfileImageUrl":"https://img-shop.pstatic.net/front/common/profile_default.png","purchasedProductName":"[10%할인] 링티 1박스 (10회분, 레몬/복숭아 선택) + 추가2포","purchasedOptionContents":"구성선택: 복숭아맛 1박스+2포 샘플","createdDate":"2020-05-22 10:43:02","best":false,"repurchase":false,"afterMonth":false,"freeTrialReview":false,"helpCount":0,"help":false,"contentType":"PHOTO","contents":"음 복숭아맛시켰는데 되게 진한 이프로맛? 샘플로 주신 파란색깔도 괜찮은 것 같아요. 확실히 수분이 충전되는 듯한 느낌은 있는데 피곤할 때 피곤함을 없애주는 것 같지는 않네요. 피곤할때보다는 운동할 때 마시면 더 좋을거같아요","comments":[],"resources":[{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20200522_274/1590111774545S9J9z_JPEG/022EC33E-9CA2-49A4-A955-6782BA4A2C8B.jpeg","type":"I","width":3024,"height":4032,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":""}],"reportable":true,"reportStatusCheckUrl":null,"userSizeText":null,"parentReviewSeq":null,"highLightedContent":"음 복숭아맛시켰는데 되게 진한 이프로맛? 샘플로 주신 파란색깔도 괜찮은 것 같아요. 확실히 수분이 충전되는 듯한 느낌은 있는데 피곤할 때 피곤함을 없애주는 것 같지는 않네요. 피곤할때보다는 운동할 때 마시면 더 좋을거같아요","channelServiceType":null,"visible":true,"eventSeq":null,"eventTitle":"","representResource":{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20200522_274/1590111774545S9J9z_JPEG/022EC33E-9CA2-49A4-A955-6782BA4A2C8B.jpeg","type":"I","width":3024,"height":4032,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":""},"reviewScorePercent":80},{"id":868620415,"reviewScore":3,"writerId":"1425****","writerProfileImageUrl":"https://img-shop.pstatic.net/front/common/profile_default.png","purchasedProductName":"[10%할인] 링티 1박스 (10회분, 레몬/복숭아 선택) + 추가2포","purchasedOptionContents":"구성선택: 복숭아맛 1박스+2포 샘플+봄 에디션 스티커","createdDate":"2020-06-03 19:26:11","best":false,"repurchase":false,"afterMonth":false,"freeTrialReview":false,"helpCount":0,"help":false,"contentType":"PHOTO","contents":"방송보구 사서 먹었는데 생각보다는 별루네요 맛이 애매합니다.","comments":[],"resources":[{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20200603_208/1591179965804mQh27_JPEG/1591179945076.jpg","type":"I","width":4032,"height":3024,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":""}],"reportable":true,"reportStatusCheckUrl":null,"userSizeText":null,"parentReviewSeq":null,"highLightedContent":"방송보구 사서 먹었는데 생각보다는 별루네요 맛이 애매합니다.","channelServiceType":null,"visible":true,"eventSeq":null,"eventTitle":"","representResource":{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20200603_208/1591179965804mQh27_JPEG/1591179945076.jpg","type":"I","width":4032,"height":3024,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":""},"reviewScorePercent":60},{"id":86 ...
# 			"number" : 2,
# 			"size" : 30,
# 			"totalPages" : 354,
# 			"totalElements" :10614
# 		}
# 	}
# }

# %%
'''
- scrapy는 정적웹크롤링 + selector + data저장 과정을 모듈화한 라이브러리이다. 
- scrapy로만 사용할수는 없고 selenium을 병행해야함
- 프로젝트 구조는 가져가고 파일로 구분해서 확장하는 식으로
- 스크립트 형식으로 test하는것 확인
- mongodb 저장하는것부터 해볼필요
- 프레임웤이라 project단위로 구조를 강제하는것같다..?
'''
