# %%
import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy import Request
import time
# Out:
# :0: UserWarning: You do not have a working installation of the service_identity module: 'cannot import name 'opentype''.  Please install it from <https://pypi.python.org/pypi/service_identity> and make sure all of its dependencies are satisfied.  Without the service_identity module, Twisted can perform only rudimentary TLS client hostname verification.  Many valid certificate/hostname mappings may be rejected.

# %%
class TestSpider(scrapy.Spider):
    name = 'test_spider'
    
    rootUrl = 'https://smartstore.naver.com/lingerwater/products/2800118009'    
    start_urls = [rootUrl]
    contents = ''
    
    def start_requests(self):
        headers = {'referer':self.rootUrl}
        cookies = {}        
        pageNum = 2
        numPerPage = 1
        totalPageNum = 0
        sortType = 'REVIEW_RANKING'
        # sortType = 'REVIEW_CREATE_DATE_DESC'
        contentType = 'ALL'
        
        # 처음 total 리뷰수 확인하려면?    
        for i in range(1, pageNum, 1):
            url = 'https://smartstore.naver.com/lingerwater/products/2796364821/reviews/page.json?page={0}&size=30&sortType={1}&contentType={2}'.format(i, sortType, contentType)
            print(url)
            yield Request(url, headers = headers, cookies = cookies, callback = self.parse, method = 'GET')
            time.sleep(1)
            
        
    def parse(self, response):        
        yield print(response.text)

# %%
# process = scrapy.crawler.CrawlerProcess()
# process.crawl(TestSpider)
# process.start()
# Out:
# 2020-01-22 11:30:47 [scrapy.utils.log] INFO: Scrapy 1.8.0 started (bot: scrapybot)
# 2020-01-22 11:30:47 [scrapy.utils.log] INFO: Versions: lxml 3.6.4.0, libxml2 2.9.4, cssselect 1.1.0, parsel 1.5.2, w3lib 1.21.0, Twisted 19.10.0, Python 3.5.6 |Anaconda 4.2.0 (64-bit)| (default, Aug 26 2018, 16:05:27) [MSC v.1900 64 bit (AMD64)], pyOpenSSL 16.2.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.8, Platform Windows-7-6.1.7601-SP1
# 2020-01-22 11:30:47 [scrapy.crawler] INFO: Overridden settings: {}
# 2020-01-22 11:30:47 [scrapy.extensions.telnet] INFO: Telnet Password: 56f1270adfe349a7
# 2020-01-22 11:30:47 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-01-22 11:30:47 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-01-22 11:30:47 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-01-22 11:30:47 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-01-22 11:30:47 [scrapy.core.engine] INFO: Spider opened
# 2020-01-22 11:30:47 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-01-22 11:30:47 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# https://smartstore.naver.com/lingerwater/products/2796364821/reviews/page.json?page=1&size=30&sortType=REVIEW_RANKING&contentType=ALL
# 2020-01-22 11:30:48 [scrapy.core.downloader.tls] WARNING: Remote certificate is not valid for hostname "smartstore.naver.com"; 'sell.smartstore.naver.com'!='smartstore.naver.com'
# 2020-01-22 11:30:49 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://smartstore.naver.com/lingerwater/products/2796364821/reviews/page.json?page=1&size=30&sortType=REVIEW_RANKING&contentType=ALL> (referer: https://smartstore.naver.com/lingerwater/products/2800118009)
# 2020-01-22 11:30:49 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-01-22 11:30:49 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 394,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 72608,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 1.303,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 1, 22, 2, 30, 49, 213601),
#  'log_count/DEBUG': 1,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 1, 22, 2, 30, 47, 910601)}
# 2020-01-22 11:30:49 [scrapy.core.engine] INFO: Spider closed (finished)
# {
# 	"bSuccess" : true,
# 	"htReturnValue" : {
# 		"message" : "",
# 		"gridType":"",
# 		"pagedResult" : {
# 			"content" : [{"id":782115585,"reviewScore":3,"writerId":"thdm****","writerProfileImageUrl":"https://img-shop.pstatic.net/front/common/profile_default.png","purchasedProductName":"[모두를 위한]링티 1박스 (10회분, 레몬/복숭아 선택)","purchasedOptionContents":"커피대신 마시자! / 링티 1박스 (10회분): 링티
channelServiceType":null,"visible":true,"eventSeq":null,"eventTitle":"","representResource":{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20191218_55/1576630963229oneEN_JPEG/KakaoTalk_20191218_085556475.jpg","type":"I","width":4032,"height":3024,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":""},"reviewScorePercent":80},{"id":772660986,"reviewScore":5,"writerId":"hyou****","writerProfileImageUrl":"https://img-shop.pstatic.net/front/common/profile_default.png","purchasedProductName":"[모두를 위한]링티 1박스 (10회분, 레몬/복숭아 선택)","purchasedOptionContents":"커피대신 마시자! / 링티 1박스 (10회분): 링티 복숭아맛 1박스 (10회분)","createdDate":"2019-12-18 10:07:41","best":false,"repurchase":false,"afterMonth":fa ...
# 			"number" : 1,
# 			"size" : 30,
# 			"totalPages" : 328,
# 			"totalElements" :9826
# 		}
# 	}
# }

# %%
from twisted.internet import reactor, defer
from scrapy.crawler import CrawlerRunner
from scrapy.utils.project import get_project_settings

# %%
runner = CrawlerRunner(get_project_settings())

@defer.inlineCallbacks
def crawl(spider):
    yield runner.crawl(spider)
    reactor.stop()

# %%
crawl(TestSpider)
reactor.run()

# %%
# Out:
# https://smartstore.naver.com/lingerwater/products/2796364821/reviews/page.json?page=1&size=30&sortType=REVIEW_RANKING&contentType=ALL
# {
# 	"bSuccess" : true,
# 	"htReturnValue" : {
# 		"message" : "",
# 		"gridType":"",
# 		"pagedResult" : {
# 			"content" : [{"id":782115585,"reviewScore":3,"writerId":"thdm****","writerProfileImageUrl":"https://img-shop.pstatic.net/front/common/profile_default.png","purchasedProductName":"[모두를 위한]링티 1박스 (10회분, 레몬/복숭아 선택)","purchasedOptionContents":"커피대신 마시자! / 링티 1박스 (10회분): 링티 복숭아맛 1박스 (10회분)","createdDate":"2020-01-08 04:07:20","best":false,"repurchase":false,"afterMonth":true,"freeTrialReview":false,"helpCount":3,"help":false,"contentType":"PHOTO","contents":"어...솔직히 말해서 저는 먹기 힘들었어요..\n제가 느끼한 음식을 못먹지는 않지만 넘길때 느글느글 거리는 느낌이 강하게 들었어요!! 엄청 시원하게 먹어도 마찬가지더라구요.. 그래도 친구들한테 먹어보라고 했더니 잘 먹는 친구들도 있었기에 개인차가 있을거라고 생각합니다!","comments":[{"id":222929445,"commentContent":"안녕하세요 고객님~ 링티입니다. 링티를 찬물과 섭취했음에도 불구하고 느글거리는 느낌이 들어 많이 힘드셨을 것 같습니다. 대중적으로 선호할만한 맛을 찾기위해 연구하고 있지만, 맛에 대한 개인적인 호불호가 있을 수 있는 부분이라 모든 고객님을 만족 시켜 드리기에 어려움이 있는 것 같습니다. 이에 대해 점차 개선을 하겠습니다. 소중한 후기 정말 감사합니다.^^","createdDate":"2020-01-08 11:18:27","blind":false}],"resources":[{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20200108_8/1578423982894RWwBh_JPEG/1B1FDF00-754F-4975-9955-333C9A3708E8.jpeg","type":"I","width":540,"height":960,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":"복숭아맛 링티 넣었을때 색깔이에요!!"}],"reportable":true,"reportStatusCheckUrl":null,"userSizeText":null,"parentReviewSeq":null,"highLightedContent":"어...솔직히 말해서 저는 먹기 힘들었어요..\n제가 느끼한 음식을 못먹지는 않지만 넘길때 느글느글 거리는 느낌이 강하게 들었어요!! 엄청 시원하게 먹어도 마찬가지더라구요.. 그래도 친구들한테 먹어보라고 했더니 잘 먹는 친구들도 있었기에 개인차가 있을거라고 생각합니다!","channelServiceType":null,"visible":true,"eventSeq":null,"eventTitle":"","representResource":{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20200108_8/1578423982894RWwBh_JPEG/1B1FDF00-754F-4975-9955-333C9A3708E8.jpeg","type":"I","width":540,"height":960,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":"복숭아맛 링티 넣었을때 색깔이에요!!"},"reviewScorePercent":60},{"id":772658563,"reviewScore":4,"writerId":"hyou****","writerProfileImageUrl":"https://img-shop.pstatic.net/front/common/profile_default.png","purchasedProductName":"[모두를 위한]링티 1박스 (10회분, 레몬/복숭아 선택)","purchasedOptionContents":"커피대신 마시자! / 링티 1박스 (10회분): 링티 레몬맛 1박스 (10회분)","createdDate":"2019-12-18 10:02:54","best":false,"repurchase":false,"afterMonth":false,"freeTrialReview":false,"helpCount":0,"help":false,"contentType":"PHOTO","contents":"레몬맛이랑 복숭아맛 둘 중 어느것이 나을까 하다가 둘다 샀어요..!\n레몬이 엄청 실것 같은데 그정도는아니여서 맛있게 잘 먹을 수 있었고 복숭아맛도 밍밍하지 않는 맛이여서 좋았어요.\n남자친구가 매일 밤샘근무에 몸은 챙겨야하고 많이 피곤한데 친구가 링티를 소개시켜주면서 정말 효과 많이 봤다고 컨디션 조절도 되고 피곤함이 싹 없어진다해서 선물용으로 구매하게 되었는데 유통기한도 2년이나되고 빠른 배송으로 지친 몸을 달랠수 있네요~\n가격이 있긴 하지만 커피보다는 싸니까 지칠때 한포씩 마시기 딱입니다!!","comments":[],"resources":[{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20191218_55/1576630963229oneEN_JPEG/KakaoTalk_20191218_085556475.jpg","type":"I","width":4032,"height":3024,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":""}],"reportable":true,"reportStatusCheckUrl":null,"userSizeText":null,"parentReviewSeq":null,"highLightedContent":"레몬맛이랑 복숭아맛 둘 중 어느것이 나을까 하다가 둘다 샀어요..!\n레몬이 엄청 실것 같은데 그정도는아니여서 맛있게 잘 먹을 수 있었고 복숭아맛도 밍밍하지 않는 맛이여서 좋았어요.\n남자친구가 매일 밤샘근무에 몸은 챙겨야하고 많이 피곤한데 친구가 링티를 소개시켜주면서 정말 효과 많이 봤다고 컨디션 조절도 되고 피곤함이 싹 없어진다해서 선물용으로 구매하게 되었는데 유통기한도 2년이나되고 빠른 배송으로 지친 몸을 달랠수 있네요~\n가격이 있긴 하지만 커피보다는 싸니까 지칠때 한포씩 마시기 딱입니다!!","channelServiceType":null,"visible":true,"eventSeq":null,"eventTitle":"","representResource":{"resourceUrl":"https://phinf.pstatic.net/checkout.phinf/20191218_55/1576630963229oneEN_JPEG/KakaoTalk_20191218_085556475.jpg","type":"I","width":4032,"height":3024,"inKey":null,"vid":null,"serviceId":null,"gifImage":false,"tagName":"","description":""},"reviewScorePercent":80},{"id":772660986,"reviewScore":5,"writerId":"hyou****","writerProfileImageUrl":"https://img-shop.pstatic.net/front/common/profile_default.png","purchasedProductName":"[모두를 위한]링티 1박스 (10회분, 레몬/복숭아 선택)","purchasedOptionContents":"커피대신 마시자! / 링티 1박스 (10회분): 링티 복숭아맛 1박스 (10회분)","createdDate":"2019-12-18 10:07:41","best":false,"repurchase":false,"afterMonth":fa ...
# 			"number" : 1,
# 			"size" : 30,
# 			"totalPages" : 328,
# 			"totalElements" :9829
# 		}
# 	}
# }
